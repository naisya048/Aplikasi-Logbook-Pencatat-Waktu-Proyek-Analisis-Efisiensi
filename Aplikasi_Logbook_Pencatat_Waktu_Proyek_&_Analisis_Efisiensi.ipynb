# %% [markdown]
# <a href="https://colab.research.google.com/github/naisya048/Aplikasi-Logbook-Pencatat-Waktu-Proyek-Analisis-Efisiensi/blob/main/Aplikasi_Logbook_Pencatat_Waktu_Proyek_%26_Analisis_Efisiensi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Survey Lapangan Menggunakan Metode Geolistrik Dalam Sebuah Pertambangan
# Aplikasi Logbook Pencatat Waktu Proyek & Analisis Efisiensi
# Dibuat oleh: Kelompok 6
# Tanggal: 25 November 2025

# Menampilkan judul biodata
print("BIODATA SAYA")
print("")
# Menampilkan data diri
print("Nama : Naisya Humaira Salsabila")
print("NIM : 124120048")
print("Nama : SANTA MONIKA BR TARIGAN")
print("NIM : 124120134")
print("Nama : Muhammad Ghufron Thamrin")
print("NIM : 124120135")
print("Nama : Raphael Silalahi")
print("NIM : 124120135")
print("Nama : Wibinandya Nugraha Putra")
print("NIM : 123120148")
print("Jurusan : Teknik Geofisika")
print("Angkatan: 2024 & 2023")
# Out:
# BIODATA SAYA
#
# Nama : Naisya Humaira Salsabila
# NIM : 124120048
# Nama : SANTA MONIKA BR TARIGAN
# NIM : 124120134
# Nama : Muhammad Ghufron Thamrin
# NIM : 124120135
# Nama : Raphael Silalahi
# NIM : 124120135
# Nama : Wibinandya Nugraha Putra
# NIM : 123120148
# Jurusan : Teknik Geofisika
# Angkatan: 2024 & 2023

# %%
import csv
import os
import matplotlib.pyplot as plt

log_file = "logbook.csv"

# Buat file CSV jika belum ada
if not os.path.exists(log_file):
    with open(log_file, mode="w", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["Hari", "Proyek", "Durasi (menit)"])


def tambah_log():
    print("\nPilih Hari Aktivitas:")
    print("1. Hari 1")
    print("2. Hari 2")
    print("3. Hari 3")
    hari = input("Masukkan pilihan hari (1/2/3): ")

    proyek = input("Masukkan nama proyek/aktivitas: ")
    durasi = float(input("Masukkan durasi pengerjaan (menit): "))

    # Simpan ke file
    with open(log_file, mode="a", newline="") as file:
        writer = csv.writer(file)
        writer.writerow([hari, proyek, durasi])

    print("Data berhasil disimpan!\n")


def tampilkan_log():
    print("\n=== DATA LOGBOOK ===")
    with open(log_file, mode="r") as file:
        reader = csv.reader(file)
        for row in reader:
            print(row)
    print()


def grafik_durasi():
    hari = []
    durasi = []

    with open(log_file, mode="r") as file:
        reader = csv.reader(file)
        next(reader)  # skip header
        for row in reader:
            hari.append("Hari " + row[0])
            durasi.append(float(row[2]))

    if len(durasi) == 0:
        print("Belum ada data untuk ditampilkan.")
        return

    plt.figure()
    plt.bar(hari, durasi)
    plt.title("Grafik Durasi Pekerjaan per Hari")
    plt.xlabel("Hari")
    plt.ylabel("Durasi (menit)")
    plt.show()


# Menu Utama
while True:
    print("=== APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===")
    print("1. Tambah Log Aktivitas")
    print("2. Tampilkan Logbook")
    print("3. Tampilkan Grafik Durasi")
    print("4. Keluar")

    menu = input("Pilih menu (1-4): ")

    if menu == "1":
        tambah_log()
    elif menu == "2":
        tampilkan_log()
    elif menu == "3":
        grafik_durasi()
    elif menu == "4":
        print("Program selesai.")
        break
    else:
        print("Menu tidak valid!\n")
# Out:
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 1
#
# Pilih Hari Aktivitas:
# 1. Hari 1
# 2. Hari 2
# 3. Hari 3
# Masukkan pilihan hari (1/2/3): 1
# Masukkan nama proyek/aktivitas: Aplikasi Logbook Pencatat Waktu Proyek & Analisis Efisiensi
# Masukkan durasi pengerjaan (menit): 300
# Data berhasil disimpan!
#
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 1
#
# Pilih Hari Aktivitas:
# 1. Hari 1
# 2. Hari 2
# 3. Hari 3
# Masukkan pilihan hari (1/2/3): 2
# Masukkan nama proyek/aktivitas: Aplikasi Logbook Pencatat Waktu Proyek & Analisis Efisiensi
# Masukkan durasi pengerjaan (menit): 420
# Data berhasil disimpan!
#
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 1
#
# Pilih Hari Aktivitas:
# 1. Hari 1
# 2. Hari 2
# 3. Hari 3
# Masukkan pilihan hari (1/2/3): 3
# Masukkan nama proyek/aktivitas: Aplikasi Logbook Pencatat Waktu Proyek & Analisis Efisiensi
# Masukkan durasi pengerjaan (menit): 324
# Data berhasil disimpan!
#
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 2
#
# === DATA LOGBOOK ===
# ['Hari', 'Proyek', 'Durasi (menit)']
# ['1', 'Aplikasi Logbook Pencatat Waktu Proyek & Analisis Efisiensi', '300.0']
# ['1', 'Aplikasi Logbook Pencatat Waktu Proyek & Analisis Efisiensi', '300.0']
# ['2', 'Aplikasi Logbook Pencatat Waktu Proyek & Analisis Efisiensi', '420.0']
# ['3', 'Aplikasi Logbook Pencatat Waktu Proyek & Analisis Efisiensi', '324.0']
#
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 3
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 4
# Program selesai.

# %%
import csv
import os
import matplotlib.pyplot as plt

log_file = "logbook.csv"

# Buat file CSV jika belum ada
if not os.path.exists(log_file):
    with open(log_file, mode="w", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["Hari", "Proyek", "Durasi (menit)"])


def tambah_log():
    print("\nPilih Hari Aktivitas:")
    for i in range(1, 8 + 1):
        print(f"{i}. Hari {i}")

    hari = input("Masukkan pilihan hari (1-8): ")

    proyek = input("Masukkan nama proyek/aktivitas: ")
    durasi = float(input("Masukkan durasi pengerjaan (menit): "))

    # Simpan ke file
    with open(log_file, mode="a", newline="") as file:
        writer = csv.writer(file)
        writer.writerow([hari, proyek, durasi])

    print("Data berhasil disimpan!\n")


def tampilkan_log():
    print("\n=== DATA LOGBOOK ===")
    with open(log_file, mode="r") as file:
        reader = csv.reader(file)
        for row in reader:
            print(row)
    print()


def grafik_durasi():
    hari = []
    durasi = []

    with open(log_file, mode="r") as file:
        reader = csv.reader(file)
        next(reader)  # skip header
        for row in reader:
            hari.append("Hari " + row[0])
            durasi.append(float(row[2]))

    if len(durasi) == 0:
        print("Belum ada data untuk ditampilkan.")
        return

    plt.figure()
    plt.bar(hari, durasi)
    plt.title("Grafik Durasi Pekerjaan per Hari")
    plt.xlabel("Hari")
    plt.ylabel("Durasi (menit)")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()


# Menu Utama
while True:
    print("=== APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===")
    print("1. Tambah Log Aktivitas")
    print("2. Tampilkan Logbook")
    print("3. Tampilkan Grafik Durasi")
    print("4. Keluar")

    menu = input("Pilih menu (1-4): ")

    if menu == "1":
        tambah_log()
    elif menu == "2":
        tampilkan_log()
    elif menu == "3":
        grafik_durasi()
    elif menu == "4":
        print("Program selesai.")
        break
    else:
        print("Menu tidak valid!\n")
# Out:
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 1
#
# Pilih Hari Aktivitas:
# 1. Hari 1
# 2. Hari 2
# 3. Hari 3
# 4. Hari 4
# 5. Hari 5
# 6. Hari 6
# 7. Hari 7
# 8. Hari 8
# Masukkan pilihan hari (1-8): 1
# Masukkan nama proyek/aktivitas: Pengajuan Proposal Survei Lapangan
# Masukkan durasi pengerjaan (menit): 60
# Data berhasil disimpan!
#
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 1
#
# Pilih Hari Aktivitas:
# 1. Hari 1
# 2. Hari 2
# 3. Hari 3
# 4. Hari 4
# 5. Hari 5
# 6. Hari 6
# 7. Hari 7
# 8. Hari 8
# Masukkan pilihan hari (1-8): 2
# Masukkan nama proyek/aktivitas: Survei Lokasi Pengukuran
# Masukkan durasi pengerjaan (menit): 100
# Data berhasil disimpan!
#
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 1
#
# Pilih Hari Aktivitas:
# 1. Hari 1
# 2. Hari 2
# 3. Hari 3
# 4. Hari 4
# 5. Hari 5
# 6. Hari 6
# 7. Hari 7
# 8. Hari 8
# Masukkan pilihan hari (1-8): 3
# Masukkan nama proyek/aktivitas: Peminjaman Alat
# Masukkan durasi pengerjaan (menit): 45
# Data berhasil disimpan!
#
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 1
#
# Pilih Hari Aktivitas:
# 1. Hari 1
# 2. Hari 2
# 3. Hari 3
# 4. Hari 4
# 5. Hari 5
# 6. Hari 6
# 7. Hari 7
# 8. Hari 8
# Masukkan pilihan hari (1-8): 4
# Masukkan nama proyek/aktivitas: Perjalanan ke Lokasi dan Pengukuran Hari Ke-1
# Masukkan durasi pengerjaan (menit): 380
# Data berhasil disimpan!
#
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 1
#
# Pilih Hari Aktivitas:
# 1. Hari 1
# 2. Hari 2
# 3. Hari 3
# 4. Hari 4
# 5. Hari 5
# 6. Hari 6
# 7. Hari 7
# 8. Hari 8
# Masukkan pilihan hari (1-8): 5
# Masukkan nama proyek/aktivitas: Pengukuran Hari ke-2
# Masukkan durasi pengerjaan (menit): 300
# Data berhasil disimpan!
#
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 1
#
# Pilih Hari Aktivitas:
# 1. Hari 1
# 2. Hari 2
# 3. Hari 3
# 4. Hari 4
# 5. Hari 5
# 6. Hari 6
# 7. Hari 7
# 8. Hari 8
# Masukkan pilihan hari (1-8): 6
# Masukkan nama proyek/aktivitas: Pengukuran Hari ke-3
# Masukkan durasi pengerjaan (menit): 300
# Data berhasil disimpan!
#
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 1
#
# Pilih Hari Aktivitas:
# 1. Hari 1
# 2. Hari 2
# 3. Hari 3
# 4. Hari 4
# 5. Hari 5
# 6. Hari 6
# 7. Hari 7
# 8. Hari 8
# Masukkan pilihan hari (1-8): 7
# Masukkan nama proyek/aktivitas: Perjalanan Pulang dan Pengolahan Data Pengukuran
# Masukkan durasi pengerjaan (menit): 560
# Data berhasil disimpan!
#
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 1
#
# Pilih Hari Aktivitas:
# 1. Hari 1
# 2. Hari 2
# 3. Hari 3
# 4. Hari 4
# 5. Hari 5
# 6. Hari 6
# 7. Hari 7
# 8. Hari 8
# Masukkan pilihan hari (1-8): 8
# Masukkan nama proyek/aktivitas: Pemaparan Hasil data Pengukuran
# Masukkan durasi pengerjaan (menit): 100
# Data berhasil disimpan!
#
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 2
#
# === DATA LOGBOOK ===
# ['Hari', 'Proyek', 'Durasi (menit)']
# ['1', 'Pengajuan Proposal Survei Lapangan', '60.0']
# ['2', 'Survei Lokasi Pengukuran', '100.0']
# ['3', 'Peminjaman Alat', '45.0']
# ['4', 'Perjalanan ke Lokasi dan Pengukuran Hari Ke-1', '380.0']
# ['5', 'Pengukuran Hari ke-2', '300.0']
# ['6', 'Pengukuran Hari ke-3', '300.0']
# ['7', 'Perjalanan Pulang dan Pengolahan Data Pengukuran', '560.0']
# ['8', 'Pemaparan Hasil data Pengukuran', '100.0']
#
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 3
# === APLIKASI LOGBOOK PENCATAT WAKTU PROYEK ===
# 1. Tambah Log Aktivitas
# 2. Tampilkan Logbook
# 3. Tampilkan Grafik Durasi
# 4. Keluar
# Pilih menu (1-4): 4
# Program selesai.
